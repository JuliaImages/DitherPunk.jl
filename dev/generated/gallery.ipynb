# %%
using DitherPunk
using Images

# %% [markdown]
# # Gallery
# A simple linear gradient works well to reveal the characteristic patterns of
# different dithering algorithms.
#
# ## Threshold dithering
# ### `threshold_dithering`

# %%
threshold_dithering |> test_on_gradient
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `random_noise_dithering`

# %%
random_noise_dithering |> test_on_gradient
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(1.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ## Ordered dithering on small images
# ### `bayer_dithering`

# %%
bayer_dithering |> test_on_gradient
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# The order of the Bayer-matrix can be specified through the parameter `level`,
# which defaults to `1`.

# %%
img = gradient_image(100, 800)
dithers = [Gray.(bayer_dithering(img; level=level)) for level in 0:4]
mosaicview([img, dithers...])
# Out:
# 600×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ## Ordered dithering on large images
# The following methods have large characteristic patterns and are therefore
# better suited for large images.
#
# ### `clustered_dots_dithering`

# %%
clustered_dots_dithering |> test_on_gradient
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `balanced_centered_point_dithering`

# %%
balanced_centered_point_dithering |> test_on_gradient
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `rhombus_dithering`

# %%
rhombus_dithering |> test_on_gradient
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, Array{ColorTypes.Gray{Float64}, 3}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
