# %%
using DitherPunk
using Images

# %% [markdown]
# # Gallery
# ## On color spaces
# A simple linear gradient works well to reveal the characteristic patterns of
# different dithering algorithms.

# %%
srbg, linear = gradient_image(100, 800);
mosaicview(srbg, linear)
# Out:
# 200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Tuple{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(9.68703e-5)     Gray{Float64}(1.0)

# %% [markdown]
# The pixel intensities in the image `srgb` increase linearly from 0 to 1.
# The second image `linear` has been converted from sRGB to a linear representation,
# which more closely matches our human perception of brightness.
#
# The helper function `test_on_gradient` takes a dithering algorithm and runs it on
# both the `srgb` and the `linear` image.
# It then shows a comparison of both inputs and outputs.
#
# Most dithering algorithms in DitherPunk.jl provide an optional parameter `to_linear`,
# which converts the input image to a linear color space before applying the dithering.
# Select what looks best!
#
# ## Threshold dithering
# ### `threshold_dithering`

# %%
test_on_gradient(threshold_dithering)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `white_noise_dithering`

# %%
test_on_gradient(white_noise_dithering)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ## Ordered dithering on small images
# ### `bayer_dithering`

# %%
test_on_gradient(bayer_dithering)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# The order of the Bayer-matrix can be specified through the parameter `level`,
# which defaults to `1`.

# %%
bayer_dithering_algs = [(img) -> (bayer_dithering(img; level=level)) for level in 4:-1:0]
test_on_gradient(bayer_dithering_algs)
# Out:
# 1200×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ## Ordered dithering on large images
# The following methods have large characteristic patterns and are therefore
# better suited for large images.
#
# ### `clustered_dots_dithering`

# %%
test_on_gradient(clustered_dots_dithering)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `balanced_centered_point_dithering`

# %%
test_on_gradient(balanced_centered_point_dithering)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `rhombus_dithering`

# %%
test_on_gradient(rhombus_dithering)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ## Error diffusion
# ### `simple_error_diffusion`

# %%
test_on_gradient(simple_error_diffusion)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `floyd_steinberg_diffusion`

# %%
test_on_gradient(floyd_steinberg_diffusion)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `jarvis_judice_diffusion`

# %%
test_on_gradient(jarvis_judice_diffusion)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `stucki_diffusion`

# %%
test_on_gradient(stucki_diffusion)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ### `atkinson_diffusion`

# %%
test_on_gradient(atkinson_diffusion)
# Out:
# 400×800 MosaicViews.MosaicView{ColorTypes.Gray{Float64}, 4, Base.ReshapedArray{ColorTypes.Gray{Float64}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Float64}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{Float64}, PaddedViews.PaddedView{ColorTypes.Gray{Float64}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Float64}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)  …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.00125156)     Gray{Float64}(1.0)
#  ⋮                                              ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)         …  Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)            Gray{Float64}(1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
