# %%
using DitherPunk
using Images
using TestImages

# %% [markdown]
# # Test image gallery
# This gallery uses images from [*TestImages.jl*](https://testimages.juliaimages.org).

# %%
function preprocess(img)
    img = Gray.(img)
    return imresize(img; ratio=1 / 2)
end

file_names = [
    "cameraman", "lake_gray", "house", "fabio_gray_512", "mandril_gray", "peppers_gray"
]
imgs = [preprocess(testimage(file)) for file in file_names]
mosaic(imgs; ncol=3)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)  …  Gray{N0f8}(0.612)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.353)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.62)      Gray{N0f8}(0.529)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.51)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.345)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)  …  Gray{N0f8}(0.275)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.6)       Gray{N0f8}(0.482)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.561)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.612)     Gray{N0f8}(0.549)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)     Gray{N0f8}(0.353)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.169)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.173)     Gray{N0f8}(0.612)
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.161)  …  Gray{N0f8}(0.643)
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.173)     Gray{N0f8}(0.741)
#  Gray{N0f8}(0.141)  Gray{N0f8}(0.157)     Gray{N0f8}(0.765)
#  Gray{N0f8}(0.133)  Gray{N0f8}(0.153)     Gray{N0f8}(0.788)
#  Gray{N0f8}(0.118)  Gray{N0f8}(0.153)     Gray{N0f8}(0.773)
#  Gray{N0f8}(0.125)  Gray{N0f8}(0.133)  …  Gray{N0f8}(0.773)
#  Gray{N0f8}(0.137)  Gray{N0f8}(0.133)     Gray{N0f8}(0.776)

# %% [markdown]
# Our test function `test_on_images` just runs a dithering algorithm on all six images
# in linear color space (`to_liner=true`).

# %%
function test_on_images(alg; to_linear=false)
    dithers = [dither(img, alg; to_linear) for img in imgs]
    return mosaic(dithers; ncol=3)
end
# Out:
# test_on_images (generic function with 1 method)

# %% [markdown]
# ## Threshold dithering
# #### `ConstantThreshold`

# %%
test_on_images(ConstantThreshold())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `WhiteNoiseThreshold`

# %%
test_on_images(WhiteNoiseThreshold())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# ## Ordered dithering
# #### Bayer matrices
# **Level 1**

# %%
test_on_images(Bayer())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# **Level 2**

# %%
test_on_images(Bayer(; level=2))
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# **Level 3**

# %%
test_on_images(Bayer(; level=3))
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# **Level 4**

# %%
test_on_images(Bayer(; level=4))
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `ClusteredDots`

# %%
test_on_images(ClusteredDots())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `CentralWhitePoint`

# %%
test_on_images(CentralWhitePoint())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `BalancedCenteredPoint`

# %%
test_on_images(BalancedCenteredPoint())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `Rhombus`

# %%
test_on_images(Rhombus())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### ImageMagick methods

# %%
test_on_images(IM_checks())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_h4x4a())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_h6x6a())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_h8x8a())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_h4x4o())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_h6x6o())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_h8x8o())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_c5x5())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %%
test_on_images(IM_c6x6())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %%
test_on_images(IM_c7x7())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)

# %% [markdown]
# ## Error diffusion
# #### `SimpleErrorDiffusion`

# %%
test_on_images(SimpleErrorDiffusion())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `FloydSteinberg`

# %%
test_on_images(FloydSteinberg())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)

# %% [markdown]
# #### `JarvisJudice`

# %%
test_on_images(JarvisJudice())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `Stucki`

# %%
test_on_images(Stucki())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `Burkes`

# %%
test_on_images(Burkes())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `Sierra`

# %%
test_on_images(Sierra())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `TwoRowSierra`

# %%
test_on_images(TwoRowSierra())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `SierraLite`

# %%
test_on_images(SierraLite())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `Fan93()`

# %%
test_on_images(Fan93())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `ShiauFan()`

# %%
test_on_images(ShiauFan())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `ShiauFan2()`

# %%
test_on_images(ShiauFan2())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)

# %% [markdown]
# #### `Atkinson()`

# %%
test_on_images(Atkinson())
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, Vector{OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)     Gray{N0f8}(0.0)  Gray{N0f8}(0.0)
#  ⋮                                 ⋱
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(0.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(1.0)  Gray{N0f8}(0.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)  …  Gray{N0f8}(1.0)  Gray{N0f8}(1.0)
#  Gray{N0f8}(0.0)  Gray{N0f8}(0.0)     Gray{N0f8}(0.0)  Gray{N0f8}(1.0)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
