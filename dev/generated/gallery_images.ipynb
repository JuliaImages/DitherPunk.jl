# %%
using DitherPunk
using Images
using ImageTransformations
using ImageContrastAdjustment
using TestImages

# %% [markdown]
# # Test image gallery
# This gallery uses images from [*TestImages.jl*](https://testimages.juliaimages.org).

# %%
function preprocess(img)
    img = Gray.(img)
    img .= adjust_histogram(img, LinearStretching()) # normalize
    return imresize(img; ratio=1 / 2)
end

file_names = [
    "cameraman", "lake_gray", "house", "fabio_gray_512", "mandril_gray", "peppers_gray"
]
imgs = [preprocess(testimage(file)) for file in file_names]
mosaicview(imgs...; ncol=3)
# Out:
#  Downloading artifact: images
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, Base.ReshapedArray{ColorTypes.Gray{FixedPointNumbers.N0f8}, 4, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{FixedPointNumbers.N0f8}, PaddedViews.PaddedView{ColorTypes.Gray{FixedPointNumbers.N0f8}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{FixedPointNumbers.N0f8}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.624)  …  Gray{N0f8}(0.69)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.4)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.62)      Gray{N0f8}(0.596)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.608)     Gray{N0f8}(0.576)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.6)       Gray{N0f8}(0.388)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)  …  Gray{N0f8}(0.31)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.6)       Gray{N0f8}(0.541)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.631)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.612)     Gray{N0f8}(0.62)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.604)     Gray{N0f8}(0.4)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.149)  Gray{N0f8}(0.173)     Gray{N0f8}(0.808)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.18)      Gray{N0f8}(0.702)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.169)  …  Gray{N0f8}(0.745)
#  Gray{N0f8}(0.149)  Gray{N0f8}(0.18)      Gray{N0f8}(0.855)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.165)     Gray{N0f8}(0.882)
#  Gray{N0f8}(0.137)  Gray{N0f8}(0.157)     Gray{N0f8}(0.91)
#  Gray{N0f8}(0.122)  Gray{N0f8}(0.157)     Gray{N0f8}(0.89)
#  Gray{N0f8}(0.133)  Gray{N0f8}(0.141)  …  Gray{N0f8}(0.89)
#  Gray{N0f8}(0.145)  Gray{N0f8}(0.137)     Gray{N0f8}(0.894)

# %% [markdown]
# Our test function `test_on_images` just runs a dithering algorithm on all six images
# in linear color space (`to_liner=true`).

# %%
function test_on_images(alg)
    dithers = [Gray.(alg(img; to_linear=true)) for img in imgs]
    return mosaicview(dithers...; ncol=3)
end
# Out:
# test_on_images (generic function with 1 method)

# %% [markdown]
# ## Threshold dithering
# #### `threshold_dithering`

# %%
test_on_images(threshold_dithering)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(true)   Gray{Bool}(true)   …  Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)   …  Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `white_noise_dithering`

# %%
test_on_images(white_noise_dithering)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(true)   Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)   …  Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# ## Ordered dithering on small images
# #### Bayer matrices

# %% [markdown]
# #### `clustered_dots_dithering`

# %%
test_on_images(clustered_dots_dithering)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `balanced_centered_point_dithering`

# %%
test_on_images(balanced_centered_point_dithering)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `rhombus_dithering`

# %%
test_on_images(rhombus_dithering)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(true)   …  Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# ## Error diffusion
# #### `simple_error_diffusion`

# %%
test_on_images(simple_error_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)

# %% [markdown]
# #### `floyd_steinberg_diffusion`

# %%
test_on_images(floyd_steinberg_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)   …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `jarvis_judice_diffusion`

# %%
test_on_images(jarvis_judice_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `stucki_diffusion`

# %%
test_on_images(stucki_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `burkes_diffusion`

# %%
test_on_images(burkes_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)

# %% [markdown]
# #### `sierra_diffusion`

# %%
test_on_images(sierra_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `two_row_sierra_diffusion`

# %%
test_on_images(two_row_sierra_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `sierra_lite_diffusion`

# %%
test_on_images(sierra_lite_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(true)   Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(true)   Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# #### `atkinson_diffusion`

# %%
test_on_images(atkinson_diffusion)
# Out:
# 512×768 MosaicViews.MosaicView{ColorTypes.Gray{Bool}, 4, Base.ReshapedArray{ColorTypes.Gray{Bool}, 4, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 3, Tuple{Base.OneTo{Int64}, Base.OneTo{Int64}, Base.OneTo{Int64}}, StackViews.StackView{ColorTypes.Gray{Bool}, 3, 3, NTuple{6, OffsetArrays.OffsetMatrix{ColorTypes.Gray{Bool}, PaddedViews.PaddedView{ColorTypes.Gray{Bool}, 2, Tuple{UnitRange{Int64}, UnitRange{Int64}}, Matrix{ColorTypes.Gray{Bool}}}}}}}, Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}, Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}:
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(true)      Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  ⋮                                     ⋱
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(false)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)  …  Gray{Bool}(true)
#  Gray{Bool}(false)  Gray{Bool}(false)     Gray{Bool}(true)

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
